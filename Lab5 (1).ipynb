# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

#ruta = '/content/drive/MyDrive/Colab_Notebooks/Miniproyecto1/'

ruta = '/content/drive/MyDrive/Señales3/ArchivosMiniProy1/'
fileName = 'DataMP1.csv'
db = pd.read_csv(ruta+fileName)

labels = db.iloc[:,43]
db = db.iloc[:,1:43]

# %%
scaler = StandardScaler()
scaler.fit(db)
print('var: ',scaler.var_)
print('mean: ',scaler.mean_)
# Out:
# var:  [9.09914921e+07 1.16350175e+00 8.80107329e+06 2.40891846e+06
#  1.20430982e+06 7.48508987e+05 4.59988747e+05 2.24229509e+05
#  2.13188961e+05 1.76411617e+05 1.39691487e+05 1.20926223e+05
#  1.97457110e+07 9.76106267e+05 4.81867736e+12 9.00496329e+10
#  1.37402642e+10 8.23330587e+03 2.13400000e+01 1.33854158e+00
#  4.08832424e-03 6.40169662e-06 1.09141177e-15 3.13110560e-18
#  1.88275000e+01 5.13612165e+00 1.19791530e+07 9.54141419e+00
#  2.30124256e+02 1.31000164e+00 1.20303327e+00 3.98813547e+03
#  1.88937906e-01 1.82400695e+00 9.44133887e-01 1.30306249e+00
#  3.25992350e+01 3.59913876e+00 3.51817233e+00 4.43392111e-02
#  7.77329918e-02 7.19682738e+01]
# mean:  [ 3.94347953e+03  3.06002000e+00  6.14889010e+03  3.43651618e+03
#   2.33328085e+03  1.76207895e+03  1.41825810e+03  1.14090518e+03
#   1.01227249e+03  8.95283623e+02  8.03581299e+02  7.12966505e+02
#   8.62228916e+02  4.33641383e+03  2.77099650e+06  3.58977844e+05
# ...

# %%
db_scaled = scaler.transform(db)

# %%
acc_train = []
acc_test = []
Nrange = 100

for it in Nrange:
  x_train, x_test, y_train, y_test = train_test_split(db_scaled,labels,test_size=0.2)

  modelRL = LogisticRegression(C = 1.0)
  modelRL.fit(x_train, y_train)

  y_est_train = modelRL.predict(x_train)
  y_est_test = modelRL.predict(y_train)

  acc_train.append(accuracy_score(y_train,y_est_train))
  acc_test.append(accuracy_score(y_test,y_est_test))

print("ACC Train: ", acc_train.mean_, "+/-", acc_train.var_)
print("ACC Test: ", acc_test.mean_, "+/-", acc_test.var_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-818e06bcdf91> in <module>
#       9
#      10 y_est_train = modelRL.predict(x_train)
# ---> 11 y_est_test = modelRL.predict(y_train)
#      12
#      13 print("ACC Train: ", accuracy_score(y_train,y_est_train))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
# ...

# %%
pca = PCA(n_components=2)
pca.fit(db) # Entrenamos el modelo PCA (Calculamos los parámetros de proyección W, autovals, autovecs)
print(db.shape)
# Out:
# (40, 42)

# %%
print(pca.explained_variance_)
# Out:
# [4.94717274e+12 9.67465298e+10]

# %%
db_pca = pca.transform(db) # Transformamos los datos al espacio latente
print("original shape:   ", db.shape)
print("transformed shape:", db_pca.shape)
# Out:
# original shape:    (40, 42)
# transformed shape: (40, 5)
